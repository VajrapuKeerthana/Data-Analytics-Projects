# %% [markdown]
# DATASET-District-Wise.csv

# %% [markdown]
# The dataset contains district-wise data from the years 2013 to 2022, where each row represents a district, and each column (from 2013 to 2022) represents numerical values associated with that district for the respective year. The dataset helps analyze trends, distributions, and comparisons across districts over time.

# %%
import pandas as pd
df=pd.read_csv("District-Wise.csv")
df
# Out:
#             Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767
# 1            Pathankot  1377   968   968   870   870   870   870   875   779
# 2             Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141
# 3           Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372
# 4           Kapurthala  1919   708   708   731   731   731   696   692   683
# 5            Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051
# 6            SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119
# 7           Hoshiarpur  4499     0     0     0     0     0     0     0     0
# 8            Roopnagar  1880     0     0     0     0     0     0     0     0
# 9            SAS Nagar  1662   778   778   685   685   685   685   716   374
# 10            Ludhiana  5588  3407  3407  3274  3274  3274  3163  3119  3233
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0    Name/ Year  22 non-null     object
#  1   2022         22 non-null     int64
#  2   2021         22 non-null     int64
#  3   2020         22 non-null     int64
#  4   2019         22 non-null     int64
#  5   2018         22 non-null     int64
#  6   2017         22 non-null     int64
#  7   2016         22 non-null     int64
#  8   2015         22 non-null     int64
#  9   2014         22 non-null     int64
#  10  2013         22 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 2.0+ KB

# %%
df.head(10)
# Out:
#    Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  2013
# 0   Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767  1767
# 1   Pathankot  1377   968   968   870   870   870   870   875   779   779
# 2    Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141  1141
# 3  Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372  1372
# 4  Kapurthala  1919   708   708   731   731   731   696   692   683   683
# 5   Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051  2051
# 6   SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119  2119
# 7  Hoshiarpur  4499     0     0     0     0     0     0     0     0     0
# 8   Roopnagar  1880     0     0     0     0     0     0     0     0     0
# 9   SAS Nagar  1662   778   778   685   685   685   685   716   374   374

# %%
len(df)
# Out:
# 22

# %%
summary = df.describe()
summary
df
# Out:
#             Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767
# 1            Pathankot  1377   968   968   870   870   870   870   875   779
# 2             Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141
# 3           Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372
# 4           Kapurthala  1919   708   708   731   731   731   696   692   683
# 5            Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051
# 6            SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119
# 7           Hoshiarpur  4499     0     0     0     0     0     0     0     0
# 8            Roopnagar  1880     0     0     0     0     0     0     0     0
# 9            SAS Nagar  1662   778   778   685   685   685   685   716   374
# 10            Ludhiana  5588  3407  3407  3274  3274  3274  3163  3119  3233
# ...

# %%
yearly_totals = df.iloc[:, 1:].sum()
print(yearly_totals)
# Out:
# 2022    63840
# 2021    31988
# 2020    31988
# 2019    30781
# 2018    30781
# 2017    30665
# 2016    29328
# 2015    28859
# 2014    28781
# 2013    27929
# dtype: int64

# %%
df.isnull().sum()
# Out:
#  Name/ Year    0
# 2022           0
# 2021           0
# 2020           0
# 2019           0
# 2018           0
# 2017           0
# 2016           0
# 2015           0
# 2014           0
# 2013           0
# dtype: int64

# %% [markdown]
# The code calculates the sum of all values for each column (excluding the first column) in the DataFrame df and prints the resulting totals.

# %%
max_region = df.loc[df['2022'].idxmax(), ' Name/ Year']
min_region = df.loc[df['2022'].idxmin(), ' Name/ Year']
print(f"Region with max value in 2022: {max_region}")
print(f"Region with min value in 2022: {min_region}")
# Out:
# Region with max value in 2022: Ludhiana
# Region with min value in 2022: Pathankot

# %% [markdown]
# The code identifies and prints the region names with the maximum and minimum values in the '2022' column of the DataFrame df

# %%
yearly_averages = df.iloc[:, 1:].mean()
print(yearly_averages)
# Out:
# 2022    2901.818182
# 2021    1454.000000
# 2020    1454.000000
# 2019    1399.136364
# 2018    1399.136364
# 2017    1393.863636
# 2016    1333.090909
# 2015    1311.772727
# 2014    1308.227273
# 2013    1269.500000
# dtype: float64

# %% [markdown]
# The code calculates the average of values for each column (excluding the first column) in the DataFrame df and prints the resulting averages

# %%
consistent_growth = df[(df.iloc[:, 1:].diff(axis=1) > 0).all(axis=1)]
print(consistent_growth[[' Name/ Year']])
# Out:
# Empty DataFrame
# Columns: [ Name/ Year]
# Index: []

# %% [markdown]
# The code filters and prints the regions (from the ' Name/ Year' column) where all yearly values show consistent growth

# %%
max_years = df.iloc[:, 1:].idxmax(axis=1)
df['Max_Year'] = max_years
print(df[[' Name/ Year', 'Max_Year']])
# Out:
#             Name/ Year Max_Year
# 0            Gurdaspur     2022
# 1            Pathankot     2022
# 2             Amritsar     2022
# 3           Tarn Taran     2022
# 4           Kapurthala     2022
# 5            Jalandhar     2022
# 6            SBS Nagar     2022
# 7           Hoshiarpur     2022
# 8            Roopnagar     2022
# 9            SAS Nagar     2022
# 10            Ludhiana     2022
# 11            Firozpur     2022
# 12             Fazilka     2022
# 13            Faridkot     2022
# 14  Shri Muktsar Sahib     2022
# 15                Moga     2022
# 16            Bathinda     2022
# 17               Mansa     2022
# 18             Sangrur     2022
# 19             Barnala     2022
# 20             Patiala     2022
# 21     Fatehgarh Sahib     2022

# %% [markdown]
# The code finds the year with the maximum value for each region, adds it as a new column 'Max_Year', and prints the region names alongside their corresponding maximum years.

# %%
cumulative_sum = df.iloc[:, 1:].cumsum()
cumulative_sum
# Out:
#      2022   2021   2020   2019   2018   2017   2016   2015   2014   2013  \
# 0    4720   1695   1695   1641   1641   1641   1641   1789   1767   1767
# 1    6097   2663   2663   2511   2511   2511   2511   2664   2546   2546
# 2   10099   5451   5451   5008   5008   5008   3641   3754   3687   3687
# 3   13211   7016   7016   6709   6709   6709   5323   5207   5059   5059
# 4   15130   7724   7724   7440   7440   7440   6019   5899   5742   5742
# 5   19045   9788   9788   9480   9480   9460   8039   7984   7793   7793
# 6   21273  12016  12016  11610  11610  11580  10159  10104   9912   9912
# 7   25772  12016  12016  11610  11610  11580  10159  10104   9912   9912
# 8   27652  12016  12016  11610  11610  11580  10159  10104   9912   9912
# 9   29314  12794  12794  12295  12295  12265  10844  10820  10286  10286
# 10  34902  16201  16201  15569  15569  15539  14007  13939  13519  13519
# 11  37732  17525  17525  16809  16809  16759  15227  15160  14713  14713
# ...

# %% [markdown]
# The code calculates the cumulative sum of values for each row (excluding the first column) in the DataFrame df

# %%
total_2022 = df['2022'].sum()
df['2022_Contribution (%)'] = (df['2022'] / total_2022) * 100
df[[' Name/ Year', '2022_Contribution (%)']]
# Out:
#             Name/ Year  2022_Contribution (%)
# 0            Gurdaspur               7.393484
# 1            Pathankot               2.156955
# 2             Amritsar               6.268797
# 3           Tarn Taran               4.874687
# 4           Kapurthala               3.005952
# 5            Jalandhar               6.132519
# 6            SBS Nagar               3.489975
# 7           Hoshiarpur               7.047306
# 8            Roopnagar               2.944862
# 9            SAS Nagar               2.603383
# 10            Ludhiana               8.753133
# 11            Firozpur               4.432957
# 12             Fazilka               4.606830
# 13            Faridkot               2.402882
# 14  Shri Muktsar Sahib               5.380639
# 15                Moga               3.477444
# 16            Bathinda               4.591165
# 17               Mansa               4.069549
# 18             Sangrur               5.264724
# ...

# %% [markdown]
# The code calculates each region's percentage of the total for 2022 and displays it alongside the region names.

# %%
df["Total"] = (
    df["2022"] + df["2021"] + df["2020"] + df["2019"] + df["2018"] +
    df["2017"] + df["2016"] + df["2015"] + df["2014"] + df["2013"]
)

# %%
avg_2022 = df['2022'].mean()
above_avg_2022 = df[df['2022'] > avg_2022]
above_avg_2022[[' Name/ Year', '2022']]
# Out:
#             Name/ Year  2022
# 0            Gurdaspur  4720
# 2             Amritsar  4002
# 3           Tarn Taran  3112
# 5            Jalandhar  3915
# 7           Hoshiarpur  4499
# 10            Ludhiana  5588
# 12             Fazilka  2941
# 14  Shri Muktsar Sahib  3435
# 16            Bathinda  2931
# 18             Sangrur  3361
# 20             Patiala  3716

# %% [markdown]
# The code filters and displays the regions where the value in 2022 is above the average for 2022, showing their names and values.

# %%
top_3_2022 = df.nlargest(3, '2022')
print(top_3_2022[[' Name/ Year', '2022']])
# Out:
#     Name/ Year  2022
# 10    Ludhiana  5588
# 0    Gurdaspur  4720
# 7   Hoshiarpur  4499

# %% [markdown]
# The code finds and prints the top 3 regions with the highest values in 2022, displaying their names and values.

# %%
df
# Out:
#             Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767
# 1            Pathankot  1377   968   968   870   870   870   870   875   779
# 2             Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141
# 3           Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372
# 4           Kapurthala  1919   708   708   731   731   731   696   692   683
# 5            Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051
# 6            SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119
# 7           Hoshiarpur  4499     0     0     0     0     0     0     0     0
# 8            Roopnagar  1880     0     0     0     0     0     0     0     0
# 9            SAS Nagar  1662   778   778   685   685   685   685   716   374
# 10            Ludhiana  5588  3407  3407  3274  3274  3274  3163  3119  3233
# ...

# %%
highest_total_row = df.loc[df["Total"].idxmax()]


print(highest_total_row)
# Out:
#  Name/ Year              Ludhiana
# 2022                         5588
# 2021                         3407
# 2020                         3407
# 2019                         3274
# 2018                         3274
# 2017                         3274
# 2016                         3163
# 2015                         3119
# 2014                         3233
# 2013                         3233
# Max_Year                     2022
# 2022_Contribution (%)    8.753133
# Total                       34972
# Name: 10, dtype: object

# %% [markdown]
# The code finds and prints the row with the highest value in the "Total" column of the DataFrame df.

# %%
lowest_total_row = df.loc[df["Total"].idxmin()]

print(lowest_total_row)
# Out:
#  Name/ Year              Roopnagar
# 2022                          1880
# 2021                             0
# 2020                             0
# 2019                             0
# 2018                             0
# 2017                             0
# 2016                             0
# 2015                             0
# 2014                             0
# 2013                             0
# Max_Year                      2022
# 2022_Contribution (%)     2.944862
# Total                         1880
# Name: 8, dtype: object

# %% [markdown]
# The code finds and prints the row with the lowest value in the "Total" column of the DataFrame df

# %%
averages = df.select_dtypes(include='number').mean()


print("Averages for numeric columns:")
print(averages)
# Out:
# Averages for numeric columns:
# 2022                      2901.818182
# 2021                      1454.000000
# 2020                      1454.000000
# 2019                      1399.136364
# 2018                      1399.136364
# 2017                      1393.863636
# 2016                      1333.090909
# 2015                      1311.772727
# 2014                      1308.227273
# 2013                      1269.500000
# 2022_Contribution (%)        4.545455
# Total                    15224.545455
# dtype: float64

# %% [markdown]
# The code calculates and prints the average of all numeric columns in the DataFrame df

# %%
consistent_year = df[['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']].std().idxmin()


print(f"The most consistent year is: {consistent_year}")
# Out:
# The most consistent year is: 2015

# %% [markdown]
# The code finds and prints the year with the lowest standard deviation (i.e., the most consistent year) from the selected years in the DataFrame df

# %%
df['YoY Growth 2013-2014'] = (df['2014'] - df['2013']) / df['2013'] * 100

# %% [markdown]
# The code calculates the Year-over-Year (YoY) growth percentage from 2013 to 2014 and stores it in a new column 'YoY Growth 2013-2014' in the DataFrame df

# %%
df
# Out:
#             Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767
# 1            Pathankot  1377   968   968   870   870   870   870   875   779
# 2             Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141
# 3           Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372
# 4           Kapurthala  1919   708   708   731   731   731   696   692   683
# 5            Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051
# 6            SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119
# 7           Hoshiarpur  4499     0     0     0     0     0     0     0     0
# 8            Roopnagar  1880     0     0     0     0     0     0     0     0
# 9            SAS Nagar  1662   778   778   685   685   685   685   716   374
# 10            Ludhiana  5588  3407  3407  3274  3274  3274  3163  3119  3233
# ...

# %%
df['YoY Growth 2015-2014'] = (df['2015'] - df['2014']) / df['2014'] * 100

# %%
df
# Out:
#             Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767
# 1            Pathankot  1377   968   968   870   870   870   870   875   779
# 2             Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141
# 3           Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372
# 4           Kapurthala  1919   708   708   731   731   731   696   692   683
# 5            Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051
# 6            SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119
# 7           Hoshiarpur  4499     0     0     0     0     0     0     0     0
# 8            Roopnagar  1880     0     0     0     0     0     0     0     0
# 9            SAS Nagar  1662   778   778   685   685   685   685   716   374
# 10            Ludhiana  5588  3407  3407  3274  3274  3274  3163  3119  3233
# ...

# %%
df['YoY Growth 2015-2016'] = (df['2016'] - df['2015']) / df['2015'] * 100

# %%
df
# Out:
#             Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767
# 1            Pathankot  1377   968   968   870   870   870   870   875   779
# 2             Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141
# 3           Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372
# 4           Kapurthala  1919   708   708   731   731   731   696   692   683
# 5            Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051
# 6            SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119
# 7           Hoshiarpur  4499     0     0     0     0     0     0     0     0
# 8            Roopnagar  1880     0     0     0     0     0     0     0     0
# 9            SAS Nagar  1662   778   778   685   685   685   685   716   374
# 10            Ludhiana  5588  3407  3407  3274  3274  3274  3163  3119  3233
# ...

# %%
df.fillna(0)
# Out:
#             Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767
# 1            Pathankot  1377   968   968   870   870   870   870   875   779
# 2             Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141
# 3           Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372
# 4           Kapurthala  1919   708   708   731   731   731   696   692   683
# 5            Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051
# 6            SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119
# 7           Hoshiarpur  4499     0     0     0     0     0     0     0     0
# 8            Roopnagar  1880     0     0     0     0     0     0     0     0
# 9            SAS Nagar  1662   778   778   685   685   685   685   716   374
# 10            Ludhiana  5588  3407  3407  3274  3274  3274  3163  3119  3233
# ...

# %%
df['Growth_2021_to_2022 (%)'] = ((df['2022'] - df['2021']) / df['2021']) * 100
highest_growth = df.loc[df['Growth_2021_to_2022 (%)'].idxmax()]
print(f"Region with highest growth (2021 to 2022): {highest_growth[' Name/ Year']} with {highest_growth['Growth_2021_to_2022 (%)']:.2f}% growth")
# Out:
# Region with highest growth (2021 to 2022): Hoshiarpur with inf% growth

# %%
yearly_medians = df.iloc[:, 1:].median()
yearly_medians
# Out:
# 2022                        2880.500000
# 2021                        1535.500000
# 2020                        1535.500000
# 2019                        1466.000000
# 2018                        1466.000000
# 2017                        1466.000000
# 2016                        1461.500000
# 2015                        1430.500000
# 2014                        1368.000000
# 2013                        1282.000000
# Max_Year                    2022.000000
# 2022_Contribution (%)          4.512061
# Total                      15885.500000
# YoY Growth 2013-2014           0.000000
# YoY Growth 2015-2014           1.317716
# YoY Growth 2015-2016           0.578035
# Growth_2021_to_2022 (%)      105.475148
# dtype: float64

# %% [markdown]
# The code calculates the median of values for each column (excluding the first column) in the DataFrame df

# %%
df
# Out:
#             Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767
# 1            Pathankot  1377   968   968   870   870   870   870   875   779
# 2             Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141
# 3           Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372
# 4           Kapurthala  1919   708   708   731   731   731   696   692   683
# 5            Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051
# 6            SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119
# 7           Hoshiarpur  4499     0     0     0     0     0     0     0     0
# 8            Roopnagar  1880     0     0     0     0     0     0     0     0
# 9            SAS Nagar  1662   778   778   685   685   685   685   716   374
# 10            Ludhiana  5588  3407  3407  3274  3274  3274  3163  3119  3233
# ...

# %%
df.fillna(0)
# Out:
#             Name/ Year  2022  2021  2020  2019  2018  2017  2016  2015  2014  \
# 0            Gurdaspur  4720  1695  1695  1641  1641  1641  1641  1789  1767
# 1            Pathankot  1377   968   968   870   870   870   870   875   779
# 2             Amritsar  4002  2788  2788  2497  2497  2497  1130  1090  1141
# 3           Tarn Taran  3112  1565  1565  1701  1701  1701  1682  1453  1372
# 4           Kapurthala  1919   708   708   731   731   731   696   692   683
# 5            Jalandhar  3915  2064  2064  2040  2040  2020  2020  2085  2051
# 6            SBS Nagar  2228  2228  2228  2130  2130  2120  2120  2120  2119
# 7           Hoshiarpur  4499     0     0     0     0     0     0     0     0
# 8            Roopnagar  1880     0     0     0     0     0     0     0     0
# 9            SAS Nagar  1662   778   778   685   685   685   685   716   374
# 10            Ludhiana  5588  3407  3407  3274  3274  3274  3163  3119  3233
# ...

# %%
rolling_avg = df.iloc[:, 1:].rolling(window=3, axis=1).mean()
rolling_avg
# Out:
#     2022  2021         2020         2019         2018         2017  \
# 0    NaN   NaN  2703.333333  1677.000000  1659.000000  1641.000000
# 1    NaN   NaN  1104.333333   935.333333   902.666667   870.000000
# 2    NaN   NaN  3192.666667  2691.000000  2594.000000  2497.000000
# 3    NaN   NaN  2080.666667  1610.333333  1655.666667  1701.000000
# 4    NaN   NaN  1111.666667   715.666667   723.333333   731.000000
# 5    NaN   NaN  2681.000000  2056.000000  2048.000000  2033.333333
# 6    NaN   NaN  2228.000000  2195.333333  2162.666667  2126.666667
# 7    NaN   NaN  1499.666667     0.000000     0.000000     0.000000
# 8    NaN   NaN   626.666667     0.000000     0.000000     0.000000
# 9    NaN   NaN  1072.666667   747.000000   716.000000   685.000000
# 10   NaN   NaN  4134.000000  3362.666667  3318.333333  3274.000000
# 11   NaN   NaN  1826.000000  1296.000000  1268.000000  1233.333333
# 12   NaN   NaN  2426.333333  2124.333333  2079.666667  2035.000000
# ...

# %% [markdown]
# The code calculates the rolling average with a window of 3 years for each row (excluding the first column) in the DataFrame df

# %%
import pandas as pd

df = pd.read_csv('KEERTHANA.csv')
print(df.columns)
# Out:
# Index([' Name/ Year', '2022', '2021', '2020', '2019', '2018', '2017', '2016',
#        '2015', '2014', '2013'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('KEERTHANA.csv')
plt.hist(df['2022'], bins=10, color='blue', edgecolor='black')
plt.title('Histogram for 2022')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['2021'], bins=10, color='green', edgecolor='black')
plt.title('Histogram for 2021')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['2019'], bins=10, color='red', edgecolor='black')
plt.title('Histogram for 2019')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['2022'], bins=10, alpha=0.5, label='2022', color='blue')
plt.hist(df['2021'], bins=10, alpha=0.5, label='2021', color='red')
plt.title('Comparison of 2022 and 2021')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.hist(df['2021'], bins=10, color='green', edgecolor='black')
plt.title('Histogram for 2018')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['2017'], bins=10, color='grey', edgecolor='black')
plt.title('Histogram for 2017')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns

sns.histplot(df.melt(id_vars=' Name/ Year', value_vars=['2022', '2021']), x='value', hue='variable', multiple='stack')
plt.title('Grouped Histogram')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
sns.kdeplot(df['2022'], color='blue', fill=True)
plt.title('Density Plot for 2022')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
df.set_index(' Name/ Year').T.plot()
plt.title('Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend(title='Name/Year')
plt.show()

# %%
plt.scatter(df['2021'], df['2022'], color='purple')
plt.title('Scatter Plot: 2021 vs 2022')
plt.xlabel('2021')
plt.ylabel('2022')
plt.show()

# %%
plt.scatter(df['2020'], df['2021'], color='purple')
plt.title('Scatter Plot: 2020 vs 2021')
plt.xlabel('2020')
plt.ylabel('2021')
plt.show()

# %%
plt.scatter(df['2018'], df['2019'], color='yellow')
plt.title('Scatter Plot: 2018 vs 2019')
plt.xlabel('2018')
plt.ylabel('2019')
plt.show()

# %%
plt.scatter(df['2021'], df['2020'], color='blue')
plt.title('Scatter Plot: 2021 vs 2020')
plt.xlabel('2021')
plt.ylabel('2020')
plt.show()

# %%
plt.scatter(df['2021'], df['2018'], color='orange')
plt.title('Scatter Plot: 2021 vs 2018')
plt.xlabel('2021')
plt.ylabel('2018')
plt.show()

# %%
sns.barplot(x=df[' Name/ Year'], y=df['2022'], palette='Blues_d')
plt.title('Bar Plot for 2022')
plt.xlabel('Name/Year')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=df[['2022', '2021', '2020']])
plt.title('Boxplot Across Years')
plt.xlabel('Year')
plt.ylabel('Values')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.boxplot(data=df.iloc[:, 1:]) 
plt.title('Boxplot Across All Years')
plt.xlabel('Year')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df[['2022', '2021', '2020', '2019']])
plt.title('Boxplot for Recent Years (2019-2022)')
plt.xlabel('Year')
plt.ylabel('Values')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(data=df[['2022', '2021', '2020', '2019']])
plt.title('Line Plot for Recent Years (2019-2022)')
plt.xlabel('Year')
plt.ylabel('Values')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(data=df[['2018', '2017', '2016', '2015']])
plt.title('Line Plot for Previous Years (2015-2018)')
plt.xlabel('Year')
plt.ylabel('Values')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(data=district_data, marker='o')
plt.title(f'Trend Over Years for {district_name}')
plt.xlabel('Year')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2840\2943138320.py in <module>
#       1 plt.figure(figsize=(8, 5))
# ----> 2 sns.lineplot(data=district_data, marker='o')
#       3 plt.title(f'Trend Over Years for {district_name}')
#       4 plt.xlabel('Year')
#       5 plt.ylabel('Values')
#
# NameError: name 'district_data' is not defined

# %%
sns.heatmap(df[['2022', '2021', '2020', '2019']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.hist(df['2022'], bins=10, alpha=0.5, label='2022', color='blue', edgecolor='black')
plt.hist(df['2021'], bins=10, alpha=0.5, label='2021', color='orange', edgecolor='black')
plt.title('Overlapping Histograms: 2022 vs 2021')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.hist(df['2021'], bins=10)
plt.title('Histogram for 2021')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['2022'])
plt.title('Seaborn Histogram for 2022')
plt.show()

# %%
sns.histplot(df['2021'], kde=True)
plt.title('Seaborn Histogram with KDE for 2021')
plt.show()

# %%
plt.hist([df['2022'], df['2021']], bins=10, stacked=True, label=['2022', '2021'])
plt.title('Stacked Histogram')
plt.legend()
plt.show()

# %%
plt.hist(df['2022'], bins=10, log=True)
plt.title('Logarithmic Histogram for 2022')
plt.show()

# %%
df.rename(columns={"Name/ Year": "District"}, inplace=True)

# %%
print(df.columns)
# Out:
# Index([' Name/ Year', '2022', '2021', '2020', '2019', '2018', '2017', '2016',
#        '2015', '2014', '2013'],
#       dtype='object')

# %% [markdown]
# # Conclusion

# %% [markdown]
# By visualizing this data through pie charts and other analytical methods, we can understand how different districts compare in a particular year and analyze their relative contributions. The dataset can be further explored using time-series analysis to study long-term trends and identify patterns. Future work can include integrating external factors (e.g., economic data, environmental data) to improve the dataset’s insights.
#
# Would you like a more specific analysis or any additional details?
